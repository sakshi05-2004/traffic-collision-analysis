# %%
#not matching
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/collision_severity_dist.png'
local_path = '/tmp/collision_severity_dist.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/weather_conditions.png'
local_path = '/tmp/weather_conditions.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/victim_age_distribution.png'
local_path = '/tmp/victim_age_distribution.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
#not matching
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Collision_Severity_vs_Total_Victims.png'
local_path = '/tmp/Collision_Severity_vs_Total_Victims.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
#not matching
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Weather_Condition_vs_Collision_Severity.png'
local_path = '/tmp/Weather_Condition_vs_Collision_Severity.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Lighting_Condition_vs_Collision_Severity.png'
local_path = '/tmp/Lighting_Condition_vs_Collision_Severity.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Num_Collisions_per_Weekday.png'
local_path = '/tmp/Num_Collisions_per_Weekday.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Spatial_Dist_Collision.png'
local_path = '/tmp/Spatial_Dist_Collision.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Collision_BY_Month.png'
local_path = '/tmp/Collision_BY_Month.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Yearly_Trend_Collisions.png'
local_path = '/tmp/Yearly_Trend_Collisions.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
#matching
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Monthly_Trend_Collisions.png'
local_path = '/tmp/Monthly_Trend_Collisions.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))

# %%
# matching
import boto3
from IPython.display import Image, display

# S3 details
bucket_name = 'trafficds71'
object_key = 'plots/Hourly_Trend_Collisions.png'
local_path = '/tmp/Hourly_Trend_Collisions.png'

# Download image from S3
s3 = boto3.client('s3')
s3.download_file(bucket_name, object_key, local_path)

# Display the image
display(Image(filename=local_path))
